# %% [markdown]
# # 인기 영화 추천 시스템 만들기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
movies=pd.read_csv("https://grepp-reco-test.s3.ap-northeast-2.amazonaws.com/tmdb_5000_movies.csv")
credits=pd.read_csv("https://grepp-reco-test.s3.ap-northeast-2.amazonaws.com/tmdb_5000_credits.csv")

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
import json

def add_genre_name(j):
    genres=[]
    ar=json.loads(j)
    for a in ar:
        genres.append(a.get("name"))
    return " ".join(sorted(genres))

movies['genre_name'] = movies.apply(lambda x: add_genre_name(x.genres), axis=1)

# %%
movies['genre_name'].head(5)
# Out:
# 0    Action Adventure Fantasy Science Fiction
# 1                    Action Adventure Fantasy
# 2                      Action Adventure Crime
# 3                 Action Crime Drama Thriller
# 4            Action Adventure Science Fiction
# Name: genre_name, dtype: object

# %%
movies.groupby('genre_name').size()
# Out:
# genre_name
#                                             28
# Action                                      21
# Action Adventure                            15
# Action Adventure Animation                   1
# Action Adventure Animation Comedy Family     5
#                                             ..
# Science Fiction Thriller                    12
# Thriller                                    23
# War                                          2
# War Western                                  1
# Western                                     18
# Length: 638, dtype: int64

# %%
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies_credits = pd.merge(movies, credits)

# %%
movies_credits
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies_credits = pd.merge(movies, credits, left_on="id", right_on="movie_id")
movies_credits
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies_credits = movies_credits.drop(columns=['homepage','title_x','title_y','status','production_countries','production_companies'])

# %%
movies_credits.info()
movies_credits.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             4803 non-null   int64
#  1   genres             4803 non-null   object
#  2   id                 4803 non-null   int64
#  3   keywords           4803 non-null   object
#  4   original_language  4803 non-null   object
#  5   original_title     4803 non-null   object
#  6   overview           4800 non-null   object
#  7   popularity         4803 non-null   float64
#  8   release_date       4802 non-null   object
#  9   revenue            4803 non-null   int64
#  10  runtime            4801 non-null   float64
#  11  spoken_languages   4803 non-null   object
#  12  tagline            3959 non-null   object
#  13  vote_average       4803 non-null   float64
#  14  vote_count         4803 non-null   int64
#  15  genres_name        4803 non-null   object
# ...

# %%
popularity
# Out:
#          budget                                             genres      id  \
# 546    74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...  211672
# 95    165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...  157336
# 788    58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  293660
# 94    170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...  118340
# 127   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   76341
# ...         ...                                                ...     ...
# 4625          0                     [{"id": 27, "name": "Horror"}]  426067
# 4118          0                                                 []  325140
# 4727          0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...   65448
# 3361          0  [{"id": 27, "name": "Horror"}, {"id": 28, "nam...   77156
# 4553          0                                                 []  380097
#
# ...

# %%
movies_credits
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801          0                                                 []  126186
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
# ...

# %%
plt.figure(figsize=(12,6))
ax=sns.barplot(
    x=movies_credits['budget'].head(10),
    y=popularity['original_title'].head(10)
)
plt.title('Most Popular by popluarity')
plt.xlabel('Score of popularity')
plt.ylabel('Movie title')
# Out:
# Text(0, 0.5, 'Movie title')

# %%
movies_credits = movies_credits.sort_values('popularity',ascending=False)

# %%
movies_credits.head()
# Out:
#         budget                                             genres      id  \
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...  211672
# 95   165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...  157336
# 788   58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  293660
# 94   170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...  118340
# 127  150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   76341
#
#                                               keywords original_language  \
# 546  [{"id": 3487, "name": "assistant"}, {"id": 179...                en
# 95   [{"id": 83, "name": "saving the world"}, {"id"...                en
# 788  [{"id": 2095, "name": "anti hero"}, {"id": 307...                en
# 94   [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 127  [{"id": 2964, "name": "future"}, {"id": 3713, ...                en
#
#               original_title  \
# 546                  Minions
# ...

# %% [markdown]
# ---

# %%
def reco(n,genre=None):
    if genre is None:
        return popularity["original_title"].head(n)
    else:
        return popularity['genres_name'].str.contains(genre)['original_title'].head(n)

# %%
print(reco(10))
# Out:
# 546                                              Minions
# 95                                          Interstellar
# 788                                             Deadpool
# 94                               Guardians of the Galaxy
# 127                                   Mad Max: Fury Road
# 28                                        Jurassic World
# 199    Pirates of the Caribbean: The Curse of the Bla...
# 82                        Dawn of the Planet of the Apes
# 200                The Hunger Games: Mockingjay - Part 1
# 88                                            Big Hero 6
# Name: original_title, dtype: object

# %%
def reco_top_scored_one(n, genre=None):
  if genre is None:
    return popularity["original_title"].head(n)
  else:
    return popularity[popularity['genres_name'].str.contains(genre)]["original_title"].head(n)

# %%
print(reco_top_scored_one(10, "Action"))
# Out:
# 788                                             Deadpool
# 94                               Guardians of the Galaxy
# 127                                   Mad Max: Fury Road
# 28                                        Jurassic World
# 199    Pirates of the Caribbean: The Curse of the Bla...
# 82                        Dawn of the Planet of the Apes
# 88                                            Big Hero 6
# 108                                   Terminator Genisys
# 26                            Captain America: Civil War
# 65                                       The Dark Knight
# Name: original_title, dtype: object
